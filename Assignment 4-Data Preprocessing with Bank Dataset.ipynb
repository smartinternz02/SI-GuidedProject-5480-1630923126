# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Assignment-4 bank.csv")
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.shape
# Out:
# (11162, 17)

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df.iloc[:10,0:5]
# Out:
#    age         job   marital  education default
# 0   59      admin.   married  secondary      no
# 1   56      admin.   married  secondary      no
# 2   41  technician   married  secondary      no
# 3   55    services   married  secondary      no
# 4   54      admin.   married   tertiary      no
# 5   42  management    single   tertiary      no
# 6   56  management   married   tertiary      no
# 7   60     retired  divorced  secondary      no
# 8   37  technician   married  secondary      no
# 9   28    services    single  secondary      no

# %%
df.marital.value_counts()
# Out:
# married     6351
# single      3518
# divorced    1293
# Name: marital, dtype: int64

# %%
df.job.value_counts()
# Out:
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: job, dtype: int64

# %%
df.month.value_counts()
# Out:
# may    2824
# aug    1519
# jul    1514
# jun    1222
# nov     943
# apr     923
# feb     776
# oct     392
# jan     344
# sep     319
# mar     276
# dec     110
# Name: month, dtype: int64

# %%
from collections import Counter as count
count(df.marital)
# Out:
# Counter({'married': 6351, 'single': 3518, 'divorced': 1293})

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
print("Before Label Encoding:",count(df['marital']))
# Out:
# Before Label Encoding: Counter({'married': 6351, 'single': 3518, 'divorced': 1293})

# %%
df['marital']=le.fit_transform(df['marital'])

# %%
print("After Label Encoding:",count(df['marital']))
# Out:
# After Label Encoding: Counter({1: 6351, 2: 3518, 0: 1293})

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.        1  secondary      no     2343     yes   no
# 1       56       admin.        1  secondary      no       45      no   no
# 2       41   technician        1  secondary      no     1270     yes   no
# 3       55     services        1  secondary      no     2476     yes   no
# 4       54       admin.        1   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar        2    primary      no        1     yes   no
# 11158   39     services        1  secondary      no      733      no   no
# 11159   32   technician        2  secondary      no       29      no   no
# 11160   43   technician        1  secondary      no        0      no  yes
# 11161   34   technician        1  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.        1  secondary      no     2343     yes   no  unknown
# 1   56      admin.        1  secondary      no       45      no   no  unknown
# 2   41  technician        1  secondary      no     1270     yes   no  unknown
# 3   55    services        1  secondary      no     2476     yes   no  unknown
# 4   54      admin.        1   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
print("Before Label Encoding:",count(df['housing']))
# Out:
# Before Label Encoding: Counter({'no': 5881, 'yes': 5281})

# %%
df['housing']=le.fit_transform(df['housing'])

# %%
print("After Label Encoding:",count(df['housing']))
# Out:
# After Label Encoding: Counter({0: 5881, 1: 5281})

# %%
df
# Out:
#        age          job  marital  education default  balance  housing loan  \
# 0       59       admin.        1  secondary      no     2343        1   no
# 1       56       admin.        1  secondary      no       45        0   no
# 2       41   technician        1  secondary      no     1270        1   no
# 3       55     services        1  secondary      no     2476        1   no
# 4       54       admin.        1   tertiary      no      184        0   no
# ...    ...          ...      ...        ...     ...      ...      ...  ...
# 11157   33  blue-collar        2    primary      no        1        1   no
# 11158   39     services        1  secondary      no      733        0   no
# 11159   32   technician        2  secondary      no       29        0   no
# 11160   43   technician        1  secondary      no        0        0  yes
# 11161   34   technician        1  secondary      no        0        0   no
#
# ...
